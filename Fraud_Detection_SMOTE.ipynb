# %%
#Importing Neccessary Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(df.shape)
# Out:
# (284807, 31)

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
describe_data = df.describe()
np.round(describe_data,10).T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  94813.859575  47488.145955    0.000000  54201.500000
# V1      284807.0      0.000000      1.958696  -56.407510     -0.920373
# V2      284807.0      0.000000      1.651309  -72.715728     -0.598550
# V3      284807.0     -0.000000      1.516255  -48.325589     -0.890365
# V4      284807.0      0.000000      1.415869   -5.683171     -0.848640
# V5      284807.0      0.000000      1.380247 -113.743307     -0.691597
# V6      284807.0      0.000000      1.332271  -26.160506     -0.768296
# V7      284807.0     -0.000000      1.237094  -43.557242     -0.554076
# V8      284807.0      0.000000      1.194353  -73.216718     -0.208630
# V9      284807.0     -0.000000      1.098632  -13.434066     -0.643098
# V10     284807.0      0.000000      1.088850  -24.588262     -0.535426
# V11     284807.0      0.000000      1.020713   -4.797473     -0.762494
# ...

# %%
#Highest and lowest amount

max = np.max(df['Amount'])
min = np.min(df['Amount'])

print(f"Highest amount is {max}")
print(f"Lowest amount is {min}")
# Out:
# Highest amount is 25691.16
# Lowest amount is 0.0

# %%
#Top 5 highest amount need to be paid to companies

df['Amount'].sort_values(ascending = False).head()
# Out:
# 274771    25691.16
# 58465     19656.53
# 151296    18910.00
# 46841     12910.93
# 54018     11898.09
# Name: Amount, dtype: float64

# %% [markdown]
# ###### *How many Frauds are there? 0 Not Fraud, 1 Fraud*

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.barplot(df['Class'].value_counts(), legend = 'auto', width = 0.7)
plt.show()

# %% [markdown]
# ##### ***As we can see, we are working with a imbalanced data where 0 (NOT FRAUD) are dominating compare to 1 (FRAUD)***

# %% [markdown]
# ### ***Handling Imbalanced Data: Fraudulent transactions are rare, so you may need to balance the dataset using techniques like SMOTE (Synthetic Minority Oversampling Technique).***

# %%
x = df.iloc[:, 1:-1]
y = df['Class']

# %% [markdown]
# ### Applying SMOTE Technique

# %% [markdown]
# ##### ***SMOTE (Synthetic Minority Over-sampling Technique) is an oversampling technique used to address class imbalance by generating synthetic samples for the minority class.***

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_res, y_res = smote.fit_resample(x, y)

print(f"Before SMOTE: {y.value_counts()}")
print(f"After SMOTE: {pd.Series(y_res).value_counts()}")
# Out:
# Before SMOTE: Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# After SMOTE: Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %% [markdown]
# ### Splitting data into Train Test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_res, y_res, test_size=0.3, random_state=42)

# %% [markdown]
# ### Building the ML Model

# %% [markdown]
# ### ***Random Forest Algorithm***

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Initialize RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
clf.fit(x_train, y_train)

# Predict on the test set
y_pred = clf.predict(x_test)

# training and testing accuracies
print(f"Training accuracy of RF Model: {clf.score(x_train,y_train)}")
print(f"Testing accuracy of RF Model: {clf.score(x_test,y_test)}")
# Out:
# Training accuracy of RF Model: 1.0
# Testing accuracy of RF Model: 0.9999003452743143

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.9999003452743143
# Confusion Matrix:
#  [[85132    17]
#  [    0 85440]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
